# %% [markdown]
# [1,1,3,3,0,1,1]	>> [1,3,0,1]
# [4,4,4,3,3]	>> [4,3]

# %%
def solution(arr):
    answer = []
    temp = None
    for k in arr:
        if k != temp: 
            answer.append(k)
        temp = k
        
    return answer
