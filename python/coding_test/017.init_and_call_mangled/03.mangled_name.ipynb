# %%
class Test:
    def __mangled_name(self):
        pass
    def normal_name(self):
        pass
    
    @classmethod
    def my_functin_name(self):
        pass

# %%
t = Test()

# %%
dir(t)
# Out:
# ['_Test__mangled_name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'my_functin_name',
#  'normal_name']

# %%
[attr for attr in dir(t) if "name" in attr]
# Out:
# ['_Test__mangled_name', 'my_functin_name', 'normal_name']
