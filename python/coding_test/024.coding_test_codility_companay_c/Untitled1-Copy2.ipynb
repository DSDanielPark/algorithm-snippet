# %%
A=
B=
C=

# %%
print(solution(A))
print(solution(B))
print(solution(C))

# %%
1. 가장작은 엣지 케이스 체크
2. 가장 큰 엣지 케이스 체크
3. 코드 효율화는 나중에
4. 테스트 케이스는 최소 3개
5. 조건 다시 체크 (음수,양수)
6. 테스트 케이스 무조건 다 넣고 할 것
7. 다 풀고 효율화 꼭하기 쉬운건 무조건 효율화 들어가야된다. %%timeit으로 꼭 체크해라
